# %%
# Write a program to count the number of words in a string without split()
# s = input('Enter the string: ')
# words = s.split()
# print(len(words))



s = input("Enter the string: ")
L = []
temp = ""
count = 0
for i in s:
    if i != " ":
        temp = temp + i
    else:
        L.append(temp)
        count += 1
        temp = ""
count += 1
print(count)
print(L)
# Out:
# Enter the string:  hi hoe are you
# 4
# ['hi', 'hoe', 'are']

# %%
# Find the length of a given string without using the len() function
s = input('Enter the string: ')
count = 0
for i in s:
    count += 1
print(count)
# Out:
# Enter the string:  my name is anas
# 15

# %%
# Extract username from a given email. 
# Eg if the email is nitish24singh@gmail.com 
# then the username should be nitish24singh

s = input('Enter the email: ')
pos = s.index('@')

print(s[:pos])
# Out:
# Enter the email:  hello@gmail.com
# hello

# %%
# Count the frequency of a particular character in a provided string. 
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.
s = input('Enter the string: ')
term = input('What you wanna search: ')

count = 0
for i in s:
    if i == term:
        count += 1
print('Frequency is', count)
# Out:
# Enter the string:  my name is anas and i am a student
# What you wanna search:  s
# Frequency is 3

# %%
# Write a program which can remove a particular character from a string.
s = input('enter the string')
term = input('what would like to remove')

temp = ""
for i in s:
    if i != term:
        temp = temp + i
print(temp)
# Out:
# enter the string hello, my name is anas and i am a student
# what would like to remove s
# hello, my name i ana and i am a tudent

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

s = input('Enter the string: ')
for i in range(0, len(s)//2):
    if s[i] != s[len(s)-i-1]:
        print("Not a palindrome")
        break
else:
    print("Palindrome")
# Out:
# Enter the string:  malayalm
# Not a palindrome

# %%
# Write a python program to convert a string to title case without using the title()
print('hi how are you'.title())
s = input('enter the string')
words = s.split()
l = []
for i in words:
    l.append(i[0].upper() + i[1:].lower())
print(" ".join(l))
# Out:
# Hi How Are You
# enter the string hi HOW aRe you BRO
# Hi How Are You Bro

# %%
# Write a program that can convert an integer to string.
number = int(input('Enter the number: '))
digits = '0123456789'
ans = ''

while number != 0:
    ans = digits[number%10] + ans
    number = number//10
print(ans)
print(type(ans))
# Out:
# Enter the number:  458
# 458
# <class 'str'>
